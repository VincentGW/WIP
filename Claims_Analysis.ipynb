# %%
'''
In Problem 2, you will prepare data for predictive modeling.
Specifically, you will look for transformations to the provided data that will make better models.

Create a summary report to share this information with a non-technical business audience:

- Identify variables that are unimportant and can be dropped.
- Identify problems with the dataset (missing values, outliers, mistakes) and document how you address them.
- Transform specific variables to make them better for analysis (this could be combining categories, converting datatypes, etc).
- Create any new features that might be beneficial. 
- For each of the above, write a brief note explaining why this is a good thing to do to non-technical person.  
- Run a regression analysis to see how well your transformed dataset predicts days in hospital (Y2
).
'''

#This is a test line to practice using got from my work computer.

import pandas as pd
import matplotlib.pyplot as plt

claims = pd.read_csv("C:/Users/vgwis/Documents/Bana780/Claims.csv")
Y1 = claims[claims['Year'] == 'Y1'].drop(columns=['Vendor'])

print(Y1.columns)

#print(Y1.groupby())

print('Specialty:')
print(Y1['Specialty'].value_counts(dropna=False))
print('PCP:')
print(Y1['PCP'].value_counts(dropna=False))
print('PlaceSvc:')
print(Y1['PlaceSvc'].value_counts(dropna=False))
print('LengthOfStay:')
print(Y1['LengthOfStay'].value_counts(dropna=False))

#print(Y1['PayDelay'].apply(lambda x: 162 if x == "162+" else x))
print('PrimaryConditionGroup:')
print(Y1['PrimaryConditionGroup'].value_counts(dropna=False))
print('CharlsonIndex:')
print(Y1['CharlsonIndex'].value_counts(dropna=False))
print('ProcedureGroup:')
print(Y1['ProcedureGroup'].value_counts(dropna=False))
print('SupLOS:')
print(Y1['SupLOS'].value_counts(dropna=False))

#days = pd.read_csv("C:/Users/vgwis/Documents/Bana780/DaysInHospital_Y2.csv")
#Clean_Y1 = df[df['MemberID'].isin(df2['MemberID'])]
# print(Clean_Y1.groupby('MemberID')['PlaceSvc'].value_counts())
# Out:
# Index(['MemberID', 'ProviderID', 'PCP', 'Year', 'Specialty', 'PlaceSvc',
#        'PayDelay', 'LengthOfStay', 'DSFS', 'PrimaryConditionGroup',
#        'CharlsonIndex', 'ProcedureGroup', 'SupLOS'],
#       dtype='object')
# Specialty:
# Specialty
# Laboratory                   215039
# Internal                     210322
# General Practice             163192
# Diagnostic Imaging            66633
# Surgery                       65827
# Emergency                     43131
# Other                         28230
# Pediatrics                    27083
# Rehabilitation                17189
# Obstetrics and Gynecology     12555
# Anesthesiology                 9746
# Pathology                      4201
# NaN                            2541
# Name: count, dtype: int64
# PCP:
# PCP
# 91972.0    27174
# 32724.0    15609
# 20893.0    13353
# 36452.0    11176
# 27467.0    10924
#            ...
# 96273.0        1
# 10448.0        1
# 99826.0        1
# 48252.0        1
# 96751.0        1
# Name: count, Length: 1006, dtype: int64
# PlaceSvc:
# PlaceSvc
# Office                 504806
# Independent Lab        216154
# Urgent Care             65888
# Outpatient Hospital     35814
# Inpatient Hospital      26302
# Ambulance                8875
# Other                    3867
# NaN                      2572
# Home                     1411
# Name: count, dtype: int64
# LengthOfStay:
# LengthOfStay
# NaN           843214
# 1 day          17940
# 2 days          2028
# 3 days          1023
# 4 days           503
# 1- 2 weeks       290
# 4- 8 weeks       266
# 2- 4 weeks       190
# 5 days           171
# 6 days            64
# Name: count, dtype: int64
# PrimaryConditionGroup:
# PrimaryConditionGroup
# MSC2a3      170683
# METAB3      106795
# ARTHSPIN     91544
# NEUMENT      54984
# RESPR4       46232
# MISCHRT      39653
# SKNAUT       34050
# GIBLEED      33946
# INFEC4       28126
# TRAUMA       25029
# HEART2       17897
# RENAL3       16412
# ROAMI        15758
# MISCL5       14791
# COPD         14150
# ODaBNCA      14000
# UTI          13935
# GYNEC1       13555
# FXDISLC      13421
# CANCRB       12812
# AMI          11611
# PRGNCY       11155
# HEMTOL        9438
# HEART4        8948
# SEIZURE       6607
# APPCHOL       5865
# CHF           3921
# NaN           3712
# PNEUM         3579
# GIOBSENT      3498
# GYNECA        3028
# STROKE        2889
# RENAL2        2650
# FLaELEC       1791
# MISCL1        1583
# CANCRA        1402
# HIPFX         1399
# METAB1        1288
# PERVALV       1068
# LIVERDZ        829
# CATAST         591
# PNCRDZ         310
# CANCRM         258
# PERINTL        252
# RENAL1         130
# SEPSIS         114
# Name: count, dtype: int64
# CharlsonIndex:
# CharlsonIndex
# 0      499183
# 1-2    351052
# 3-4     13923
# 5+       1531
# Name: count, dtype: int64
# ProcedureGroup:
# ProcedureGroup
# EM      343043
# PL      161615
# MED     118872
# SCS      90419
# RAD      85093
# SDS      19594
# SIS      17727
# SMS       9122
# ANES      5273
# SGS       2357
# SEOA      2275
# SNS       2274
# SRS       2056
# SAS       1871
# SUS       1714
# SMCD      1164
# NaN       1122
# SO          98
# Name: count, dtype: int64
# SupLOS:
# SupLOS
# 0    862374
# 1      3315
# Name: count, dtype: int64
